# %% [markdown]
# For this project you will visualize time series data using a line chart, bar chart, and box plots. You will use Pandas, Matplotlib, and Seaborn to visualize a dataset containing the number of page views each day on the freeCodeCamp.org forum from 2016-05-09 to 2019-12-03. The data visualizations will help you understand the patterns in visits and identify yearly and monthly growth.

# %% [markdown]
# We will do some commands to finish this task:
# - Use Pandas to import the data from "fcc-forum-pageviews.csv". Set the index to the date column.

# %%
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt

# %%
df=pd.read_csv('fcc-forum-pageviews.csv'
               ,parse_dates=[0]
               ,index_col=[0])

# %%
df.head()
# Out:
#             value
# date
# 2016-05-09   1201
# 2016-05-10   2329
# 2016-05-11   1716
# 2016-05-12  10539
# 2016-05-13   6933

# %%
df.dtypes
# Out:
# value    int64
# dtype: object

# %% [markdown]
# - Clean the data by filtering out days when the page views were in the top 2.5% of the dataset or bottom 2.5% of the dataset.

# %%
print(df['value'].quantile(0.25))
print(df['value'].quantile(0.75))
# Out:
# 35757.75
# 83883.0

# %%
incorrect=df[(df['value']>=df['value'].quantile(0.75)) |(df['value']<=df['value'].quantile(0.25)) ].index

# %%
df.drop(incorrect,inplace=True)

# %% [markdown]
# Create a draw_line_plot function that uses Matplotlib to draw a line chart, The label on the x axis should be Date and the label on the y axis should be Page Views.

# %%
plt.figure(figsize=(20,6))
plt.title('Daily FreeCodeCamp Forum Page Views 5/2016-12/2019',size=20)
plt.plot(df,c='red')
plt.ylabel('Page Viwes',size=20)
# Out:
# Text(0, 0.5, 'Page Viwes')

# %% [markdown]
# Create a draw_bar_plot function that draws a bar chart. It should show average daily page views for each month grouped by year. The legend should show month labels and have a title of Months. On the chart, the label on the x axis should be Years and the label on the y axis should be Average Page Views.

# %%
df.head()
# Out:
#             value
# date
# 2016-05-09   1201
# 2016-05-10   2329
# 2016-05-11   1716
# 2016-05-12  10539
# 2016-05-13   6933

# %%
df.reset_index('date').pivot(index=None,columns='date',values='value')
# Out:
# date  2016-05-09  2016-05-10  2016-05-11  2016-05-12  2016-05-13  2016-05-14  \
# 0         1201.0         NaN         NaN         NaN         NaN         NaN
# 1            NaN      2329.0         NaN         NaN         NaN         NaN
# 2            NaN         NaN      1716.0         NaN         NaN         NaN
# 3            NaN         NaN         NaN     10539.0         NaN         NaN
# 4            NaN         NaN         NaN         NaN      6933.0         NaN
# ...          ...         ...         ...         ...         ...         ...
# 1299         NaN         NaN         NaN         NaN         NaN         NaN
# 1300         NaN         NaN         NaN         NaN         NaN         NaN
# 1301         NaN         NaN         NaN         NaN         NaN         NaN
# 1302         NaN         NaN         NaN         NaN         NaN         NaN
# 1303         NaN         NaN         NaN         NaN         NaN         NaN
#
# date  2016-05-15  2016-05-16  2016-05-17  2016-05-18  ...  2019-11-24  \
# 0            NaN         NaN         NaN         NaN  ...         NaN
# 1            NaN         NaN         NaN         NaN  ...         NaN
# 2            NaN         NaN         NaN         NaN  ...         NaN
# 3            NaN         NaN         NaN         NaN  ...         NaN
# 4            NaN         NaN         NaN         NaN  ...         NaN
# ...          ...         ...         ...         ...  ...         ...
# 1299         NaN         NaN         NaN         NaN  ...         NaN
# 1300         NaN         NaN         NaN         NaN  ...         NaN
# 1301         NaN         NaN         NaN         NaN  ...         NaN
# 1302         NaN         NaN         NaN         NaN  ...         NaN
# 1303         NaN         NaN         NaN         NaN  ...         NaN
#
# date  2019-11-25  2019-11-26  2019-11-27  2019-11-28  2019-11-29  2019-11-30  \
# 0            NaN         NaN         NaN         NaN         NaN         NaN
# 1            NaN         NaN         NaN         NaN         NaN         NaN
# 2            NaN         NaN         NaN         NaN         NaN         NaN
# 3            NaN         NaN         NaN         NaN         NaN         NaN
# 4            NaN         NaN         NaN         NaN         NaN         NaN
# ...          ...         ...         ...         ...         ...         ...
# 1299         NaN         NaN         NaN         NaN    171584.0         NaN
# 1300         NaN         NaN         NaN         NaN         NaN    141161.0
# 1301         NaN         NaN         NaN         NaN         NaN         NaN
# 1302         NaN         NaN         NaN         NaN         NaN         NaN
# 1303         NaN         NaN         NaN         NaN         NaN         NaN
#
# date  2019-12-01  2019-12-02  2019-12-03
# 0            NaN         NaN         NaN
# 1            NaN         NaN         NaN
# 2            NaN         NaN         NaN
# 3            NaN         NaN         NaN
# 4            NaN         NaN         NaN
# ...          ...         ...         ...
# 1299         NaN         NaN         NaN
# 1300         NaN         NaN         NaN
# 1301    142918.0         NaN         NaN
# 1302         NaN    220144.0         NaN
# 1303         NaN         NaN    158549.0
#
# [1304 rows x 1304 columns]

# %%
df['day']=df.index.day
df['month']=df.index.month
df['year']=df.index.year

# %%
df_new=df

# %%
df_new.reset_index(drop=True,inplace=True)

# %%
df_new.pivot(index='month',columns='year',values='value')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-80-524e3ef2bdd3> in <module>
# ----> 1 df_new.pivot(index='month',columns='year',values='value')
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in pivot(self, index, columns, values)
#    6877         from pandas.core.reshape.pivot import pivot
#    6878
# -> 6879         return pivot(self, index=index, columns=columns, values=values)
#    6880
#    6881     _shared_docs[
#
# ~\anaconda3\lib\site-packages\pandas\core\reshape\pivot.py in pivot(data, index, columns, values)
#     459         else:
#     460             indexed = data._constructor_sliced(data[values]._values, index=index)
# --> 461     return indexed.unstack(columns)
#     462
#     463
#
# ~\anaconda3\lib\site-packages\pandas\core\series.py in unstack(self, level, fill_value)
#    3827         from pandas.core.reshape.reshape import unstack
#    3828
# -> 3829         return unstack(self, level, fill_value)
#    3830
#    3831     # ----------------------------------------------------------------------
#
# ~\anaconda3\lib\site-packages\pandas\core\reshape\reshape.py in unstack(obj, level, fill_value)
#     428         if is_extension_array_dtype(obj.dtype):
#     429             return _unstack_extension_series(obj, level, fill_value)
# --> 430         unstacker = _Unstacker(
#     431             obj.index, level=level, constructor=obj._constructor_expanddim
#     432         )
#
# ~\anaconda3\lib\site-packages\pandas\core\reshape\reshape.py in __init__(self, index, level, constructor)
#     116             raise ValueError("Unstacked DataFrame is too big, causing int32 overflow")
#     117
# --> 118         self._make_selectors()
#     119
#     120     @cache_readonly
#
# ~\anaconda3\lib\site-packages\pandas\core\reshape\reshape.py in _make_selectors(self)
#     165
#     166         if mask.sum() < len(self.index):
# --> 167             raise ValueError("Index contains duplicate entries, cannot reshape")
#     168
#     169         self.group_index = comp_index
#
# ValueError: Index contains duplicate entries, cannot reshape

# %%
df_new=df_new.groupby(['year','month']).sum()

# %%
df_new.pivot()
# Out:
#               value
# year month
# 2016 5       258582
#      6       573731
#      7       722741
#      8       962525
#      9      1244306
#      10      849348
#      11     1213459
#      12      862805
# 2017 1      1016340
#      2       871166
#      3       910442
#      4       926362
#      5      1061573
#      6      1307325
#      7      2040012
#      8      1479086
#      9      1421304
#      10     1470600
#      11     1731047
#      12     1501038
# 2018 1      1815983
#      2      1839012
#      3      1943507
#      4      1870525
#      5      1753449
#      6      2103510
#      7      1971323
#      8      1947780
#      9      1978252
#      10     3490352
#      11     2360650
#      12     2481472
# 2019 1      3163752
#      2      2967114
#      3      2827649
#      4      2681053
#      5      2834637
#      6      4872078
#      7      3124938
#      8      3657722
#      9      2918065
#      10     4676744
#      11     5430801
#      12      521611

# %%
df.drop(columns='day',inplace=True)

# %%
df_new=df.groupby(['year','month']).sum()

# %%
df1 = pd.DataFrame({'foo': ['one', 'one', 'one', 'two', 'two',
                           'two'],
                   'bar': ['A', 'B', 'C', 'A', 'B', 'C'],
                   'baz': [1, 2, 3, 4, 5, 6],
                   'zoo': ['x', 'y', 'z', 'q', 'w', 't']})

# %%
df1
# Out:
#    foo bar  baz zoo
# 0  one   A    1   x
# 1  one   B    2   y
# 2  one   C    3   z
# 3  two   A    4   q
# 4  two   B    5   w
# 5  two   C    6   t

# %%
df1.pivot(index='foo',columns='bar',values='baz')
# Out:
# bar  A  B  C
# foo
# one  1  2  3
# two  4  5  6

# %%
df
# Out:
#        value  month  year
# 0       1201      5  2016
# 1       2329      5  2016
# 2       1716      5  2016
# 3      10539      5  2016
# 4       6933      5  2016
# ...      ...    ...   ...
# 1299  171584     11  2019
# 1300  141161     11  2019
# 1301  142918     12  2019
# 1302  220144     12  2019
# 1303  158549     12  2019
#
# [1304 rows x 3 columns]

# %%
df_new=pd.pivot_table(df,index='year',columns='month',values='value',aggfunc=np.sum)

# %%
df_new.plot(kind='bar',figsize=(16,8))
# Out:
# <AxesSubplot:xlabel='year'>

# %%
df_new.columns.value
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-100-1d4ac54edae7> in <module>
# ----> 1 df_new.columns.value
#
# AttributeError: 'Int64Index' object has no attribute 'value'
